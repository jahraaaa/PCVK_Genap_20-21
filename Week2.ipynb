# %% [markdown]
# <a href="https://colab.research.google.com/github/jahraaaa/PCVK_Genap_20-21/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

#Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Kucing-Munchkin.png')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB) #Konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/Kucing-Munchkin.png', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#Simpan file image
#cv.imwrite('/content/drive/MyDrive/PVCK/kitten01.jpg', img5)

#Tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))   #Ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))    #Nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
# Green-Blue (Remove Red)
import cv2
import numpy as np

img_tg1a = cv2.imread('/content/drive/MyDrive/Kucing-Munchkin.png', cv2.COLOR_BGR2RGB)
img_tg1a[:,:,2] = np.zeros([img_tg1a.shape[0], img_tg1a.shape[1]])
plt.imshow(img_tg1a)

# %%
# Red-Green (Remove Blue)
img_tg1b = cv2.imread('/content/drive/MyDrive/Kucing-Munchkin.png', cv2.COLOR_BGR2RGB)
img_tg1b[:,:,0] = np.zeros([img_tg1b.shape[0], img_tg1b.shape[1]])
plt.imshow(img_tg1b)

# %%
img_tg2 = cv.imread('/content/drive/MyDrive/Kucing-Munchkin.png')
plt.imshow(img_tg2[10:100,10:100])

# %%
img_tg3 = cv.imread('/content/drive/MyDrive/Kucing-Munchkin.png', cv.IMREAD_GRAYSCALE)
plt.imshow(img_tg3[5:30], cmap='Greens')

# %%
img_tg4 = cv.imread('/content/drive/MyDrive/Kucing-Munchkin.png')

cv.rectangle(img_tg4,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=5)
plt.imshow(img_tg4)

# %%
img_tg5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)
ax.imshow(img_tg5)

# %%
img_tg6 = cv.imread('/content/drive/MyDrive/Kucing-Munchkin.png')

cv.rectangle(img_tg6,pt1=(300,100),pt2=(500,300),color=(0,255,0),thickness=5)
cv.circle(img_tg6,center=(400,200),radius=50,color=(255,0,0),thickness=5)
plt.imshow(img_tg6)

# %%
img_tg7 = cv.imread('/content/drive/MyDrive/Kucing-Munchkin.png')
img_rgb7 = cv.cvtColor(img_tg7, cv.COLOR_BGR2RGB)

cv.rectangle(img_rgb7,pt1=(0,600),pt2=(100,500),color=(0,255,0),thickness=5)
plt.imshow(img_rgb7)

# %%
#Red-Green
img_rg = img.copy()
img_rg[:,:,2] = 0
plt.imshow(img_rg)

# %%
#Green-Blue
img_gb = img
img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %%
img_k = img[10:100,10:100]
plt.imshow(img_k)

# %%
plt.imshow(img[5:30])

# %%
imageWithRectangle = cv.cvtColor(img,cv.COLOR_BGR2RGB)
fig = plt.figure(figsize=(10,10))
cv.rectangle(imageWithRectangle, pt1=(400,200), pt2=(200,50), color=(0,255, 255), thickness = 15)
cv.rectangle(imageWithRectangle, pt1=(400,250), pt2=(150,100), color=(0,255,0), thickness = 10)
cv.rectangle(imageWithRectangle, pt1=(700,150), pt2=(250,300), color=(255,255,255), thickness = 10)
cv.rectangle(imageWithRectangle, pt1=(100,150), pt2=(50,200), color=(255,0,0), thickness = 10)
cv.rectangle(imageWithRectangle, pt1=(200,200), pt2=(120,120), color=(0,0,255),thickness= 7)
plt.imshow(imageWithRectangle)

# %%
img_t = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)
ax.imshow(img_t)

# %%
img = cv.imread('/content/drive/MyDrive/Kucing-Munchkin.png')
fig = plt.figure(figsize=(5,5))

ax = fig.add_subplot(111)
cv.rectangle(img, pt1=(300,300), pt2=(100,100), color=(255, 0, 30), thickness = 10)
cv.circle(img, center=(190, 200), radius=150, color=(180, 105, 255), thickness = 10)
ax.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))

# %%
img = cv.imread('/content/drive/MyDrive/Kucing-Munchkin.png')
fig = plt.figure(figsize=(5,5))

ax = fig.add_subplot(111)
cv.rectangle(img, pt1=(300,300), pt2=(100,100), color=(255, 0, 30), thickness = 10)
cv.circle(img, center=(190, 200), radius=150, color=(180, 105, 255), thickness = 10)
cv.rectangle(img,pt1=(0, 500),pt2=(100, 400),color=(0, 0, 255),thickness = 10)
ax.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
